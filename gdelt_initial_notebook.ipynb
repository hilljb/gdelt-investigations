# %% [markdown]
# # Introduction to Spark with GDELT Data
#
# Note that this notebook is using a slightly older version of Spark and is in Python 2.
#
# Below is my standard collection of imports for doing analytics with Spark. This is being loaded in a Dockerized Conda environment talking to Spark.

# %%
from __future__ import print_function

import time

import pandas as pd
pd.set_option('display.max_columns', None)

import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline

import warnings # current version of seaborns generates warnings
warnings.filterwarnings("ignore")

import seaborn as sns
sns.set(style="white", color_codes=True)

from pyspark.sql import SparkSession

# %% [markdown]
# I don't know that you always need Hive support. A lot of times, I use custom UDFs that are in a Java jar and I need to register those functions with Spark SQL, and Hive support is needed for that. In any case, we need a Spark session and context and this is how we grab it.

# %%
spark = SparkSession.builder.enableHiveSupport().getOrCreate()

# %% [markdown]
# ## Load Data
#
# This takes a while. Spark is running through the data and making sure it has a good idea of what the schema looks like. Depending on what your data format is, this can be faster or slower. Avro seems to be really fast, because the file headers give the schema without needing to read all the data. JSON is a bit slower, as Spark needs to read the data to obtain the schema.

# %%
path = '/opt/datadir/data/gdelt/events'

events_df = spark.read.json(path)

events_df.printSchema()
# Out:
# root
#  |-- ActionGeo_ADM1Code: string (nullable = true)
#  |-- ActionGeo_ADM2Code: string (nullable = true)
#  |-- ActionGeo_CountryCode: string (nullable = true)
#  |-- ActionGeo_FeatureID: string (nullable = true)
#  |-- ActionGeo_FullName: string (nullable = true)
#  |-- ActionGeo_Lat: double (nullable = true)
#  |-- ActionGeo_Long: string (nullable = true)
#  |-- ActionGeo_Type: long (nullable = true)
#  |-- Actor1Code: string (nullable = true)
#  |-- Actor1CountryCode: string (nullable = true)
#  |-- Actor1EthnicCode: string (nullable = true)
#  |-- Actor1Geo_ADM1Code: string (nullable = true)
#  |-- Actor1Geo_ADM2Code: string (nullable = true)
#  |-- Actor1Geo_CountryCode: string (nullable = true)
#  |-- Actor1Geo_FeatureID: string (nullable = true)
#  |-- Actor1Geo_FullName: string (nullable = true)
#  |-- Actor1Geo_Lat: double (nullable = true)
#  |-- Actor1Geo_Long: string (nullable = true)
#  |-- Actor1Geo_Type: long (nullable = true)
#  |-- Actor1KnownGroupCode: string (nullable = true)
#  |-- Actor1Name: string (nullable = true)
#  |-- Actor1Religion1Code: string (nullable = true)
#  |-- Actor1Religion2Code: string (nullable = true)
#  |-- Actor1Type1Code: string (nullable = true)
#  |-- Actor1Type2Code: string (nullable = true)
#  |-- Actor1Type3Code: string (nullable = true)
#  |-- Actor2Code: string (nullable = true)
#  |-- Actor2CountryCode: string (nullable = true)
#  |-- Actor2EthnicCode: string (nullable = true)
#  |-- Actor2Geo_ADM1Code: string (nullable = true)
#  |-- Actor2Geo_ADM2Code: string (nullable = true)
#  |-- Actor2Geo_CountryCode: string (nullable = true)
#  |-- Actor2Geo_FeatureID: string (nullable = true)
#  |-- Actor2Geo_FullName: string (nullable = true)
#  |-- Actor2Geo_Lat: double (nullable = true)
#  |-- Actor2Geo_Long: string (nullable = true)
#  |-- Actor2Geo_Type: long (nullable = true)
#  |-- Actor2KnownGroupCode: string (nullable = true)
#  |-- Actor2Name: string (nullable = true)
#  |-- Actor2Religion1Code: string (nullable = true)
#  |-- Actor2Religion2Code: string (nullable = true)
#  |-- Actor2Type1Code: string (nullable = true)
#  |-- Actor2Type2Code: string (nullable = true)
#  |-- Actor2Type3Code: string (nullable = true)
#  |-- AvgTone: double (nullable = true)
#  |-- CAMEOCodeDescription: string (nullable = true)
#  |-- DATEADDED: long (nullable = true)
#  |-- EventBaseCode: string (nullable = true)
#  |-- EventCode: string (nullable = true)
#  |-- EventRootCode: string (nullable = true)
#  |-- FractionDate: double (nullable = true)
#  |-- GLOBALEVENTID: long (nullable = true)
#  |-- GoldsteinScale: double (nullable = true)
#  |-- IsRootEvent: long (nullable = true)
#  |-- MonthYear: long (nullable = true)
#  |-- NumArticles: long (nullable = true)
#  |-- NumMentions: long (nullable = true)
#  |-- NumSources: long (nullable = true)
#  |-- QuadClass: long (nullable = true)
#  |-- SOURCEURL: string (nullable = true)
#  |-- SQLDATE: long (nullable = true)
#  |-- year: integer (nullable = true)
#  |-- month: integer (nullable = true)
#  |-- day: integer (nullable = true)

# %%
events_df.head(5)
# Out:
# [Row(ActionGeo_ADM1Code=u'CH04', ActionGeo_ADM2Code=u'13155', ActionGeo_CountryCode=u'CH', ActionGeo_FeatureID=u'-3865821', ActionGeo_FullName=u'Zhongyuan, Jiangsu, China', ActionGeo_Lat=32.3771, ActionGeo_Long=u'120.194', ActionGeo_Type=4, Actor1Code=u'CHN', Actor1CountryCode=u'CHN', Actor1EthnicCode=None, Actor1Geo_ADM1Code=u'CH04', Actor1Geo_ADM2Code=u'13155', Actor1Geo_CountryCode=u'CH', Actor1Geo_FeatureID=u'-3865821', Actor1Geo_FullName=u'Zhongyuan, Jiangsu, China', Actor1Geo_Lat=32.3771, Actor1Geo_Long=u'120.194', Actor1Geo_Type=4, Actor1KnownGroupCode=None, Actor1Name=u'CHINA', Actor1Religion1Code=None, Actor1Religion2Code=None, Actor1Type1Code=None, Actor1Type2Code=None, Actor1Type3Code=None, Actor2Code=None, Actor2CountryCode=None, Actor2EthnicCode=None, Actor2Geo_ADM1Code=None, Actor2Geo_ADM2Code=None, Actor2Geo_CountryCode=None, Actor2Geo_FeatureID=None, Actor2Geo_FullName=None, Actor2Geo_Lat=None, Actor2Geo_Long=None, Actor2Geo_Type=0, Actor2KnownGroupCode=None, Actor2Name=None, Actor2Religion1Code=None, Actor2Religion2Code=None, Actor2Type1Code=None, Actor2Type2Code=None, Actor2Type3Code=None, AvgTone=-4.1614123581, CAMEOCodeDescription=u' Cooperate economically', DATEADDED=20180520003000, EventBaseCode=u'061', EventCode=u'061', EventRootCode=u'06', FractionDate=2017.3836, GLOBALEVENTID=757486222, GoldsteinScale=6.4, IsRootEvent=1, MonthYear=201705, NumArticles=5, NumMentions=5, NumSources=1, QuadClass=2, SOURCEURL=u'http://www.businessinsider.com/r-cutting-200-billion-from-us-china-trade-deficit-is-a-tall-order-2018-5', SQLDATE=20170520, year=2017, month=5, day=20),
#  Row(ActionGeo_ADM1Code=u'USVA', ActionGeo_ADM2Code=None, ActionGeo_CountryCode=u'US', ActionGeo_FeatureID=u'1760674', ActionGeo_FullName=u'Liberty University, Virginia, United States', ActionGeo_Lat=37.3507, ActionGeo_Long=u'-79.1809', ActionGeo_Type=3, Actor1Code=u'EDU', Actor1CountryCode=None, Actor1EthnicCode=None, Actor1Geo_ADM1Code=u'USVA', Actor1Geo_ADM2Code=u'VA680', Actor1Geo_CountryCode=u'US', Actor1Geo_FeatureID=u'1760674', Actor1Geo_FullName=u'Liberty University, Virginia, United States', Actor1Geo_Lat=37.3507, Actor1Geo_Long=u'-79.1809', Actor1Geo_Type=3, Actor1KnownGroupCode=None, Actor1Name=u'UNIVERSITY', Actor1Religion1Code=None, Actor1Religion2Code=None, Actor1Type1Code=u'EDU', Actor1Type2Code=None, Actor1Type3Code=None, Actor2Code=u'GOV', Actor2CountryCode=None, Actor2EthnicCode=None, Actor2Geo_ADM1Code=u'USVA', Actor2Geo_ADM2Code=None, Actor2Geo_CountryCode=u'US', Actor2Geo_FeatureID=u'1760674', Actor2Geo_FullName=u'Liberty University, Virginia, United States', Actor2Geo_Lat=37.3507, Actor2Geo_Long=u'-79.1809', Actor2Geo_Type=3, Actor2KnownGroupCode=None, Actor2Name=u'PRESIDENT', Actor2Religion1Code=None, Actor2Religion2Code=None, Actor2Type1Code=u'GOV', Actor2Type2Code=None, Actor2Type3Code=None, AvgTone=5.4121565362, CAMEOCodeDescription=u' Host a visit', DATEADDED=20180520003000, EventBaseCode=u'043', EventCode=u'043', EventRootCode=u'04', FractionDate=2017.3836, GLOBALEVENTID=757486223, GoldsteinScale=2.8, IsRootEvent=1, MonthYear=201705, NumArticles=10, NumMentions=10, NumSources=1, QuadClass=1, SOURCEURL=u'http://www.ssuchronicle.com/2018/05/19/president-jimmy-carter-spurs-liberty-university-class-of-2018-to-success-through-service/', SQLDATE=20170520, year=2017, month=5, day=20),
#  Row(ActionGeo_ADM1Code=u'USVA', ActionGeo_ADM2Code=None, ActionGeo_CountryCode=u'US', ActionGeo_FeatureID=u'1760674', ActionGeo_FullName=u'Liberty University, Virginia, United States', ActionGeo_Lat=37.3507, ActionGeo_Long=u'-79.1809', ActionGeo_Type=3, Actor1Code=u'GOV', Actor1CountryCode=None, Actor1EthnicCode=None, Actor1Geo_ADM1Code=u'USVA', Actor1Geo_ADM2Code=u'VA680', Actor1Geo_CountryCode=u'US', Actor1Geo_FeatureID=u'1760674', Actor1Geo_FullName=u'Liberty University, Virginia, United States', Actor1Geo_Lat=37.3507, Actor1Geo_Long=u'-79.1809', Actor1Geo_Type=3, Actor1KnownGroupCode=None, Actor1Name=u'PRESIDENT', Actor1Religion1Code=None, Actor1Religion2Code=None, Actor1Type1Code=u'GOV', Actor1Type2Code=None, Actor1Type3Code=None, Actor2Code=u'EDU', Actor2CountryCode=None, Actor2EthnicCode=None, Actor2Geo_ADM1Code=u'USVA', Actor2Geo_ADM2Code=None, Actor2Geo_CountryCode=u'US', Actor2Geo_FeatureID=u'1760674', Actor2Geo_FullName=u'Liberty University, Virginia, United States', Actor2Geo_Lat=37.3507, Actor2Geo_Long=u'-79.1809', Actor2Geo_Type=3, Actor2KnownGroupCode=None, Actor2Name=u'UNIVERSITY', Actor2Religion1Code=None, Actor2Religion2Code=None, Actor2Type1Code=u'EDU', Actor2Type2Code=None, Actor2Type3Code=None, AvgTone=5.4121565362, CAMEOCodeDescription=u' Make a visit', DATEADDED=20180520003000, EventBaseCode=u'042', EventCode=u'042', EventRootCode=u'04', FractionDate=2017.3836, GLOBALEVENTID=757486224, GoldsteinScale=1.9, IsRootEvent=1, MonthYear=201705, NumArticles=10, NumMentions=10, NumSources=1, QuadClass=1, SOURCEURL=u'http://www.ssuchronicle.com/2018/05/19/president-jimmy-carter-spurs-liberty-university-class-of-2018-to-success-through-service/', SQLDATE=20170520, year=2017, month=5, day=20),
#  Row(ActionGeo_ADM1Code=u'RP', ActionGeo_ADM2Code=None, ActionGeo_CountryCode=u'RP', ActionGeo_FeatureID=u'RP', ActionGeo_FullName=u'Philippines', ActionGeo_Lat=13.0, ActionGeo_Long=u'122.0', ActionGeo_Type=1, Actor1Code=u'PHL', Actor1CountryCode=u'PHL', Actor1EthnicCode=None, Actor1Geo_ADM1Code=u'RP', Actor1Geo_ADM2Code=None, Actor1Geo_CountryCode=u'RP', Actor1Geo_FeatureID=u'RP', Actor1Geo_FullName=u'Philippines', Actor1Geo_Lat=13.0, Actor1Geo_Long=u'122.0', Actor1Geo_Type=1, Actor1KnownGroupCode=None, Actor1Name=u'PHILIPPINE', Actor1Religion1Code=None, Actor1Religion2Code=None, Actor1Type1Code=None, Actor1Type2Code=None, Actor1Type3Code=None, Actor2Code=u'CHR', Actor2CountryCode=None, Actor2EthnicCode=None, Actor2Geo_ADM1Code=u'RP', Actor2Geo_ADM2Code=None, Actor2Geo_CountryCode=u'RP', Actor2Geo_FeatureID=u'RP', Actor2Geo_FullName=u'Philippines', Actor2Geo_Lat=13.0, Actor2Geo_Long=u'122.0', Actor2Geo_Type=1, Actor2KnownGroupCode=None, Actor2Name=u'CHRISTIAN', Actor2Religion1Code=u'CHR', Actor2Religion2Code=None, Actor2Type1Code=None, Actor2Type2Code=None, Actor2Type3Code=None, AvgTone=0.2699055331, CAMEOCodeDescription=u' Make statement, not specified below', DATEADDED=20180520003000, EventBaseCode=u'010', EventCode=u'010', EventRootCode=u'01', FractionDate=2017.3836, GLOBALEVENTID=757486225, GoldsteinScale=0.0, IsRootEvent=0, MonthYear=201705, NumArticles=1, NumMentions=1, NumSources=1, QuadClass=1, SOURCEURL=u'http://www.asianjournal.com/judge-overturns-californias-physician-assisted-suicide-law/', SQLDATE=20170520, year=2017, month=5, day=20),
#  Row(ActionGeo_ADM1Code=u'RP', ActionGeo_ADM2Code=None, ActionGeo_CountryCode=u'RP', ActionGeo_FeatureID=u'RP', ActionGeo_FullName=u'Philippines', ActionGeo_Lat=13.0, ActionGeo_Long=u'122.0', ActionGeo_Type=1, Actor1Code=u'PHL', Actor1CountryCode=u'PHL', Actor1EthnicCode=None, Actor1Geo_ADM1Code=u'RP', Actor1Geo_ADM2Code=None, Actor1Geo_CountryCode=u'RP', Actor1Geo_FeatureID=u'RP', Actor1Geo_FullName=u'Philippines', Actor1Geo_Lat=13.0, Actor1Geo_Long=u'122.0', Actor1Geo_Type=1, Actor1KnownGroupCode=None, Actor1Name=u'PHILIPPINE', Actor1Religion1Code=None, Actor1Religion2Code=None, Actor1Type1Code=None, Actor1Type2Code=None, Actor1Type3Code=None, Actor2Code=u'CHR', Actor2CountryCode=None, Actor2EthnicCode=None, Actor2Geo_ADM1Code=u'RP', Actor2Geo_ADM2Code=None, Actor2Geo_CountryCode=u'RP', Actor2Geo_FeatureID=u'RP', Actor2Geo_FullName=u'Philippines', Actor2Geo_Lat=13.0, Actor2Geo_Long=u'122.0', Actor2Geo_Type=1, Actor2KnownGroupCode=None, Actor2Name=u'CHRISTIAN', Actor2Religion1Code=u'CHR', Actor2Religion2Code=None, Actor2Type1Code=None, Actor2Type2Code=None, Actor2Type3Code=None, AvgTone=0.2699055331, CAMEOCodeDescription=u' Reject, not specified below', DATEADDED=20180520003000, EventBaseCode=u'120', EventCode=u'120', EventRootCode=u'12', FractionDate=2017.3836, GLOBALEVENTID=757486226, GoldsteinScale=-4.0, IsRootEvent=0, MonthYear=201705, NumArticles=1, NumMentions=1, NumSources=1, QuadClass=3, SOURCEURL=u'http://www.asianjournal.com/judge-overturns-californias-physician-assisted-suicide-law/', SQLDATE=20170520, year=2017, month=5, day=20)]

# %% [markdown]
# Make a temp table. This allows us to run SQL queries on the JSON data. Spark isn't doing much at this point.

# %%
events_df.createOrReplaceTempView('events')

# %%
query = """
select * from events limit 100
"""

results_df = spark.sql(query)

# %% [markdown]
# Pushing the Spark dataframe into a Pandas dataframe makes printing easier. In the imports above, you can see that we've told Pandas to display all columns.

# %%
results_df.toPandas().head()
# Out:
#   ActionGeo_ADM1Code ActionGeo_ADM2Code ActionGeo_CountryCode  \
# 0               CH04              13155                    CH
# 1               USVA               None                    US
# 2               USVA               None                    US
# 3                 RP               None                    RP
# 4                 RP               None                    RP
#
#   ActionGeo_FeatureID                           ActionGeo_FullName  \
# 0            -3865821                    Zhongyuan, Jiangsu, China
# 1             1760674  Liberty University, Virginia, United States
# 2             1760674  Liberty University, Virginia, United States
# 3                  RP                                  Philippines
# 4                  RP                                  Philippines
#
#    ActionGeo_Lat ActionGeo_Long  ActionGeo_Type Actor1Code Actor1CountryCode  \
# 0        32.3771        120.194               4        CHN               CHN
# 1        37.3507       -79.1809               3        EDU              None
# 2        37.3507       -79.1809               3        GOV              None
# 3        13.0000          122.0               1        PHL               PHL
# 4        13.0000          122.0               1        PHL               PHL
#
#   Actor1EthnicCode Actor1Geo_ADM1Code Actor1Geo_ADM2Code  \
# 0             None               CH04              13155
# 1             None               USVA              VA680
# 2             None               USVA              VA680
# 3             None                 RP               None
# 4             None                 RP               None
#
#   Actor1Geo_CountryCode Actor1Geo_FeatureID  \
# 0                    CH            -3865821
# 1                    US             1760674
# 2                    US             1760674
# 3                    RP                  RP
# 4                    RP                  RP
#
#                             Actor1Geo_FullName  Actor1Geo_Lat Actor1Geo_Long  \
# 0                    Zhongyuan, Jiangsu, China        32.3771        120.194
# 1  Liberty University, Virginia, United States        37.3507       -79.1809
# 2  Liberty University, Virginia, United States        37.3507       -79.1809
# 3                                  Philippines        13.0000          122.0
# 4                                  Philippines        13.0000          122.0
#
#    Actor1Geo_Type Actor1KnownGroupCode  Actor1Name Actor1Religion1Code  \
# 0               4                 None       CHINA                None
# 1               3                 None  UNIVERSITY                None
# 2               3                 None   PRESIDENT                None
# 3               1                 None  PHILIPPINE                None
# 4               1                 None  PHILIPPINE                None
#
#   Actor1Religion2Code Actor1Type1Code Actor1Type2Code Actor1Type3Code  \
# 0                None            None            None            None
# 1                None             EDU            None            None
# 2                None             GOV            None            None
# 3                None            None            None            None
# 4                None            None            None            None
#
#   Actor2Code Actor2CountryCode Actor2EthnicCode Actor2Geo_ADM1Code  \
# 0       None              None             None               None
# 1        GOV              None             None               USVA
# 2        EDU              None             None               USVA
# 3        CHR              None             None                 RP
# 4        CHR              None             None                 RP
#
#   Actor2Geo_ADM2Code Actor2Geo_CountryCode Actor2Geo_FeatureID  \
# 0               None                  None                None
# 1               None                    US             1760674
# 2               None                    US             1760674
# 3               None                    RP                  RP
# 4               None                    RP                  RP
#
#                             Actor2Geo_FullName  Actor2Geo_Lat Actor2Geo_Long  \
# 0                                         None            NaN           None
# 1  Liberty University, Virginia, United States        37.3507       -79.1809
# 2  Liberty University, Virginia, United States        37.3507       -79.1809
# 3                                  Philippines        13.0000          122.0
# 4                                  Philippines        13.0000          122.0
#
#    Actor2Geo_Type Actor2KnownGroupCode  Actor2Name Actor2Religion1Code  \
# 0               0                 None        None                None
# 1               3                 None   PRESIDENT                None
# 2               3                 None  UNIVERSITY                None
# 3               1                 None   CHRISTIAN                 CHR
# 4               1                 None   CHRISTIAN                 CHR
#
#   Actor2Religion2Code Actor2Type1Code Actor2Type2Code Actor2Type3Code  \
# 0                None            None            None            None
# 1                None             GOV            None            None
# 2                None             EDU            None            None
# 3                None            None            None            None
# 4                None            None            None            None
#
#     AvgTone                  CAMEOCodeDescription       DATEADDED  \
# 0 -4.161412                Cooperate economically  20180520003000
# 1  5.412157                          Host a visit  20180520003000
# 2  5.412157                          Make a visit  20180520003000
# 3  0.269906   Make statement, not specified below  20180520003000
# 4  0.269906           Reject, not specified below  20180520003000
#
#   EventBaseCode EventCode EventRootCode  FractionDate  GLOBALEVENTID  \
# 0           061       061            06     2017.3836      757486222
# 1           043       043            04     2017.3836      757486223
# 2           042       042            04     2017.3836      757486224
# 3           010       010            01     2017.3836      757486225
# 4           120       120            12     2017.3836      757486226
#
#    GoldsteinScale  IsRootEvent  MonthYear  NumArticles  NumMentions  \
# 0             6.4            1     201705            5            5
# 1             2.8            1     201705           10           10
# 2             1.9            1     201705           10           10
# 3             0.0            0     201705            1            1
# 4            -4.0            0     201705            1            1
#
#    NumSources  QuadClass                                          SOURCEURL  \
# 0           1          2  http://www.businessinsider.com/r-cutting-200-b...
# 1           1          1  http://www.ssuchronicle.com/2018/05/19/preside...
# 2           1          1  http://www.ssuchronicle.com/2018/05/19/preside...
# 3           1          1  http://www.asianjournal.com/judge-overturns-ca...
# 4           1          3  http://www.asianjournal.com/judge-overturns-ca...
#
#     SQLDATE  year  month  day
# 0  20170520  2017      5   20
# 1  20170520  2017      5   20
# 2  20170520  2017      5   20
# 3  20170520  2017      5   20
# 4  20170520  2017      5   20

# %% [markdown]
# ## ETL the Data
#
# I want to get the hosts serving the events, chopping off any event data from the hostname. We can do that with some substring parsing in SQL. I'm also only going to grab the data that I want for my investigation.

# %%
query = """
select
    AvgTone as avg_tone,
    CAMEOCodeDescription as code_desc,
    EventCode as event_code,
    EventRootCode as event_root_code,
    IsRootEvent as is_root_event,
    NumArticles as num_articles,
    NumMentions as num_mentions,
    substring_index(substring_index(SOURCEURL, '//', -1), '/', 1) as source_url,
    year, month, day
from events
limit 1000
"""

results_df = spark.sql(query)

results_df.toPandas().head(100)
# Out:
#      avg_tone                                          code_desc event_code  \
# 0   -4.161412                             Cooperate economically        061
# 1    5.412157                                       Host a visit        043
# 2    5.412157                                       Make a visit        042
# 3    0.269906                Make statement, not specified below        010
# 4    0.269906                        Reject, not specified below        120
# 5   -2.318487                       Consult, not specified below        040
# 6    0.269906                Make statement, not specified below        010
# 7    0.269906                        Reject, not specified below        120
# 8    0.269906                Make statement, not specified below        010
# 9    0.269906                        Reject, not specified below        120
# 10   0.269906                Make statement, not specified below        010
# 11   0.269906                        Reject, not specified below        120
# 12  -3.978780        No Description returned for CAMEO code 1014       1014
# 13  -3.978780        No Description returned for CAMEO code 1014       1014
# 14  -3.978780        No Description returned for CAMEO code 1014       1014
# 15  -3.978780        No Description returned for CAMEO code 1014       1014
# 16  -3.978780        No Description returned for CAMEO code 1014       1014
# 17  -3.978780        No Description returned for CAMEO code 1014       1014
# 18  -0.706714         Accede to demands for change in leadership       0831
# 19  -3.852890                      Threaten, not specified below        130
# 20  -3.852890                      Threaten, not specified below        130
# 21  -3.852890                           Make pessimistic comment        012
# 22  -7.792208  Make an appeal for, request, or suggest sharin...       0214
# 23  -3.432494                       Consult, not specified below        040
# 24  -3.852890                      Threaten, not specified below        130
# 25  -3.852890                      Threaten, not specified below        130
# 26  -3.852890                           Make pessimistic comment        012
# 27  -3.432494                       Consult, not specified below        040
# 28  -0.680272                Make statement, not specified below        010
# 29  -0.839161                        Reject, not specified below        120
# ..        ...                                                ...        ...
# 70  -0.340716                       Consult, not specified below        040
# 71   2.584493                       Consult, not specified below        040
# 72   0.716479                                       Host a visit        043
# 73  -3.066271   Engage in diplomatic cooperation, not specifi...        050
# 74   0.273224   Use conventional military force, not specifie...        190
# 75 -10.175439                                       Make a visit        042
# 76  -6.836461       Arrest, detain, or charge with legal action         173
# 77  -0.340716                                       Make a visit        042
# 78  -0.340716                                       Make a visit        042
# 79  -5.122951                Express intent to meet or negotiate        036
# 80  -2.845850   Express intent allow international involvemen...       0356
# 81  -3.066271   Engage in diplomatic cooperation, not specifi...        050
# 82   0.162075                       Consult, not specified below        040
# 83   0.162075                                       Host a visit        043
# 84   1.866667                                       Make a visit        042
# 85   1.866667                                       Make a visit        042
# 86  -1.408451                       Consult, not specified below        040
# 87  -1.408451   Use conventional military force, not specifie...        190
# 88  -9.448819       Arrest, detain, or charge with legal action         173
# 89  -3.854390   Use conventional military force, not specifie...        190
# 90  -3.854390   Use conventional military force, not specifie...        190
# 91   2.584493                        Appeal, not specified below        020
# 92   2.571082                       Consult, not specified below        040
# 93  -0.503145                                       Host a visit        043
# 94 -10.204082                        Accuse, not specified below        112
# 95   2.571082                        Reject, not specified below        120
# 96  -2.318487                                  Praise or endorse        051
# 97  -2.845850                      Threaten, not specified below        130
# 98  -2.845850                      Threaten, not specified below        130
# 99   0.498008                    Retreat or surrender militarily       0874
#
#    event_root_code  is_root_event  num_articles  num_mentions  \
# 0               06              1             5             5
# 1               04              1            10            10
# 2               04              1            10            10
# 3               01              0             1             1
# 4               12              0             1             1
# 5               04              1             4             4
# 6               01              0             3             3
# 7               12              0             3             3
# 8               01              0             4             4
# 9               12              0             4             4
# 10              01              0             1             1
# 11              12              0             1             1
# 12              10              0             1             1
# 13              10              0             1             1
# 14              10              0             1             1
# 15              10              0             1             1
# 16              10              0             3             3
# 17              10              0             3             3
# 18              08              1            10            10
# 19              13              1             7             7
# 20              13              1             1             1
# 21              01              1             8             8
# 22              02              1             2             2
# 23              04              1             2             2
# 24              13              1             1             1
# 25              13              1             1             1
# 26              01              1             2             2
# 27              04              1             2             2
# 28              01              1             4             4
# 29              12              1             2             2
# ..             ...            ...           ...           ...
# 70              04              0            10            10
# 71              04              1             3             3
# 72              04              0             1             1
# 73              05              0             4             4
# 74              19              1             4             4
# 75              04              1            10            10
# 76              17              1             1             1
# 77              04              0             4             4
# 78              04              0             2             2
# 79              03              1             2             2
# 80              03              1             1             1
# 81              05              0             1             1
# 82              04              0             2             2
# 83              04              0             1             1
# 84              04              1             8             8
# 85              04              1             2             2
# 86              04              1             4             4
# 87              19              1             4             4
# 88              17              1            10            10
# 89              19              0            10            14
# 90              19              0             6             6
# 91              02              1             3             3
# 92              04              1            40            40
# 93              04              1            12            12
# 94              11              1            10            10
# 95              12              1            40            40
# 96              05              0             3             3
# 97              13              0             4             4
# 98              13              0             1             1
# 99              08              1            10            10
#
#                  source_url  year  month  day
# 0   www.businessinsider.com  2017      5   20
# 1      www.ssuchronicle.com  2017      5   20
# 2      www.ssuchronicle.com  2017      5   20
# 3      www.asianjournal.com  2017      5   20
# 4      www.asianjournal.com  2017      5   20
# 5   www.orlandosentinel.com  2017      5   20
# 6      www.asianjournal.com  2017      5   20
# 7      www.asianjournal.com  2017      5   20
# 8      www.asianjournal.com  2017      5   20
# 9      www.asianjournal.com  2017      5   20
# 10     www.asianjournal.com  2017      5   20
# 11     www.asianjournal.com  2017      5   20
# 12              www.msn.com  2018      5   20
# 13              www.msn.com  2018      5   20
# 14              www.msn.com  2018      5   20
# 15              www.msn.com  2018      5   20
# 16              www.msn.com  2018      5   20
# 17              www.msn.com  2018      5   20
# 18     www.samoaobserver.ws  2018      5   20
# 19      www.dailymail.co.uk  2018      5   20
# 20      www.dailymail.co.uk  2018      5   20
# 21      www.dailymail.co.uk  2018      5   20
# 22  www.businessinsider.com  2018      5   20
# 23         www.wacotrib.com  2018      5   20
# 24      www.dailymail.co.uk  2018      5   20
# 25      www.dailymail.co.uk  2018      5   20
# 26      www.dailymail.co.uk  2018      5   20
# 27         www.wacotrib.com  2018      5   20
# 28               tucson.com  2018      5   20
# 29       www.delcotimes.com  2018      5   20
# ..                      ...   ...    ...  ...
# 70        indianexpress.com  2018      5   20
# 71          journalstar.com  2018      5   20
# 72     www.centralmaine.com  2018      5   20
# 73            www.yahoo.com  2018      5   20
# 74      www.fox25boston.com  2018      5   20
# 75         www.dnaindia.com  2018      5   20
# 76    www.nbclosangeles.com  2018      5   20
# 77        indianexpress.com  2018      5   20
# 78        indianexpress.com  2018      5   20
# 79      www.dailymail.co.uk  2018      5   20
# 80       theiranproject.com  2018      5   20
# 81            www.yahoo.com  2018      5   20
# 82   www.bignewsnetwork.com  2018      5   20
# 83   www.bignewsnetwork.com  2018      5   20
# 84      www.loopjamaica.com  2018      5   20
# 85      www.loopjamaica.com  2018      5   20
# 86             www.krgv.com  2018      5   20
# 87             www.krgv.com  2018      5   20
# 88       www.moneyweb.co.za  2018      5   20
# 89         www.dnaindia.com  2018      5   20
# 90         www.dnaindia.com  2018      5   20
# 91          journalstar.com  2018      5   20
# 92        www.lmtonline.com  2018      5   20
# 93           www.wxii12.com  2018      5   20
# 94    www.heraldtribune.com  2018      5   20
# 95        www.lmtonline.com  2018      5   20
# 96  www.orlandosentinel.com  2018      5   20
# 97       theiranproject.com  2018      5   20
# 98       theiranproject.com  2018      5   20
# 99      newberryjournal.com  2018      5   20
#
# [100 rows x 11 columns]

# %% [markdown]
# We're going to save the data in Parquet format. This is a columnar format that makes specific queries (especially analytics queries) far faster. It also makes some queries slower. When we save, Spark will automatically snappy compress the files.

# %%
query = """
select
    AvgTone as avg_tone,
    CAMEOCodeDescription as code_desc,
    EventCode as event_code,
    EventRootCode as event_root_code,
    IsRootEvent as is_root_event,
    NumArticles as num_articles,
    NumMentions as num_mentions,
    substring_index(substring_index(SOURCEURL, '//', -1), '/', 1) as source_url,
    year, month, day
from events
"""

filepath_parquet = "/opt/datadir/data/gdelt_etl/tone_and_source/"

spark.sql(query).write.parquet(filepath_parquet, mode="overwrite")

# %% [markdown]
# ## Load the Saved Data and Query
#
# We've gone from having 220GB of data in JSON format to having around 1.4GB. This will make our queries far faster.

# %%
filepath_parquet = "/opt/datadir/data/gdelt_etl/tone_and_source/"

df_parquet = spark.read.parquet(filepath_parquet)

df_parquet.createOrReplaceTempView('events_parquet')

# %% [markdown]
# Some queries are very fast. Because we're looking at columnar data, counts are very fast.

# %%
import time

query = """
select count(*) as num from events_parquet
"""

start_time = time.time()
spark.sql(query).show()
elapsed_time = time.time() - start_time
print(elapsed_time)
# Out:
# +---------+
# |      num|
# +---------+
# |146010251|
# +---------+
#
# 0.750168085098

# %% [markdown]
# Spark can do exact percentile values, and these can take some time. There is also an approximate percentile function which runs far faster. Here, we'll use the exact method.

# %%
query = """
select
    year, month,
    count(*) as events,
    avg(avg_tone) as mean_tone,
    percentile(avg_tone, 0.1) as p10_tone,
    percentile(avg_tone, 0.25) as p25_tone,
    percentile(avg_tone, 0.5) as p50_tone,
    percentile(avg_tone, 0.75) as p75_tone,
    percentile(avg_tone, 0.9) as p90_tone
from events_parquet
where year = 2018
group by year, month
order by year, month
"""

start_time = time.time()
dfp = spark.sql(query).toPandas()
elapsed_time = time.time() - start_time
print(elapsed_time)
# Out:
# 23.0223920345

# %%
dfp.head(100)
# Out:
#     year  month   events  mean_tone  p10_tone  p25_tone  p50_tone  p75_tone  \
# 0   2018      1  5051092  -2.078976 -7.106599 -4.485050 -1.846591  0.552486
# 1   2018      2  4837577  -2.079025 -7.152875 -4.591440 -1.875000  0.619195
# 2   2018      3  5585566  -1.909961 -6.868687 -4.304636 -1.709402  0.684932
# 3   2018      4  5361310  -2.042566 -7.025761 -4.516129 -1.851852  0.595948
# 4   2018      5  5518302  -1.843049 -6.809339 -4.211957 -1.639344  0.740741
# 5   2018      6  5039461  -1.834840 -6.727829 -4.155844 -1.624884  0.704225
# 6   2018      7  4990580  -1.995033 -6.923077 -4.388489 -1.814882  0.594354
# 7   2018      8  5139643  -2.154502 -7.151442 -4.674221 -2.005420  0.546448
# 8   2018      9  4916944  -2.040082 -7.047872 -4.552469 -1.898734  0.672453
# 9   2018     10  5323981  -1.892544 -6.825939 -4.310345 -1.757632  0.727273
# 10  2018     11  5057920  -1.928618 -6.944444 -4.393305 -1.744186  0.699636
# 11  2018     12  4322609  -2.063968 -7.080292 -4.525547 -1.927438  0.595238
#
#     p90_tone
# 0   2.578269
# 1   2.694611
# 2   2.759740
# 3   2.673147
# 4   2.823529
# 5   2.748414
# 6   2.685185
# 7   2.631579
# 8   2.790698
# 9   2.843602
# 10  2.850356
# 11  2.777778

# %% [markdown]
# Let's take a list of known sites that are unreputable or highly divisive. We're going to have to use a case block which was formed in a text editor to search for instances of these sites, since we aren't sure how they'll always show up in the data.

# %%
query = """
select
    sq0.year as year,
    sq0.month as month,
    count(*) as num,
    sum(sq0.not_reputable) as not_reputable
    from (
        select
        CASE
            WHEN source_url LIKE "%nationalreport.net%" THEN 1
            WHEN source_url LIKE "%huzlers.com%" THEN 1
            WHEN source_url LIKE "%infowars.com%" THEN 1
            WHEN source_url LIKE "%theonion.com%" THEN 1
            WHEN source_url LIKE "%empirenews.net%" THEN 1
            WHEN source_url LIKE "%activistpost.com%" THEN 1
            WHEN source_url LIKE "%americannews.com%" THEN 1
            WHEN source_url LIKE "%christwire.org%" THEN 1
            WHEN source_url LIKE "%civictribune.com%" THEN 1
            WHEN source_url LIKE "%duffelblog.com%" THEN 1
            WHEN source_url LIKE "%en.mediamass.net%" THEN 1
            WHEN source_url LIKE "%naturalnews.com%" THEN 1
            WHEN source_url LIKE "%realnewsrightnow.com%" THEN 1
            WHEN source_url LIKE "%rilenews.com%" THEN 1
            WHEN source_url LIKE "%thedcgazette.com%" THEN 1
            WHEN source_url LIKE "%worldnewsdailyreport.com%" THEN 1
            WHEN source_url LIKE "%21stcenturywire.com%" THEN 1
            WHEN source_url LIKE "%70news.wordpress.com%" THEN 1
            WHEN source_url LIKE "%beforeitsnews.com%" THEN 1
            WHEN source_url LIKE "%breitbart.com%" THEN 1
            WHEN source_url LIKE "%clickhole.com%" THEN 1
            WHEN source_url LIKE "%coasttocoastam.com%" THEN 1
            WHEN source_url LIKE "%consciouslifenews.com%" THEN 1
            WHEN source_url LIKE "%conservativeoutfitters.com%" THEN 1
            WHEN source_url LIKE "%countdowntozerotime.com%" THEN 1
            WHEN source_url LIKE "%creambmp.com%" THEN 1
            WHEN source_url LIKE "%dailybuzzlive.com%" THEN 1
            WHEN source_url LIKE "%disclose.tv%" THEN 1
            WHEN source_url LIKE "%empiresports.co%" THEN 1
            WHEN source_url LIKE "%globalresearch.ca%" THEN 1
            WHEN source_url LIKE "%newslo.com%" THEN 1
            WHEN source_url LIKE "%newsmutiny.com%" THEN 1
            WHEN source_url LIKE "%veteranstoday.com%" THEN 1
            WHEN source_url LIKE "%worldtruth.tv%" THEN 1
            WHEN source_url LIKE "%abcnews.com.co%" THEN 1
            WHEN source_url LIKE "%addictinginfo.org%" THEN 1
            WHEN source_url LIKE "%bipartisanreport.com%" THEN 1
            WHEN source_url LIKE "%bluenationreview.com%" THEN 1
            WHEN source_url LIKE "%chronicle.su%" THEN 1
            WHEN source_url LIKE "%counterpsyops.com%" THEN 1
            WHEN source_url LIKE "%dailycurrant.com%" THEN 1
            WHEN source_url LIKE "%dcclothesline.com%" THEN 1
            WHEN source_url LIKE "%duhprogressive.com%" THEN 1
            WHEN source_url LIKE "%enduringvision.com%" THEN 1
            WHEN source_url LIKE "%fprnradio.com%" THEN 1
            WHEN source_url LIKE "%geoengineeringwatch.org%" THEN 1
            WHEN source_url LIKE "%govtslaves.info%" THEN 1
            WHEN source_url LIKE "%gulagbound.com%" THEN 1
            WHEN source_url LIKE "%hangthebankers.com%" THEN 1
            WHEN source_url LIKE "%intellihub.com%" THEN 1
            WHEN source_url LIKE "%jonesreport.com%" THEN 1
            WHEN source_url LIKE "%lewrockwell.com%" THEN 1
            WHEN source_url LIKE "%libertymovementradio.com%" THEN 1
            WHEN source_url LIKE "%libertytalk.fm%" THEN 1
            WHEN source_url LIKE "%newsbiscuit.com%" THEN 1
            WHEN source_url LIKE "%newswire-24.com%" THEN 1
            WHEN source_url LIKE "%nodisinfo.com%" THEN 1
            WHEN source_url LIKE "%now8news.com%" THEN 1
            WHEN source_url LIKE "%nowtheendbegins.com%" THEN 1
            WHEN source_url LIKE "%pakalertpress.com%" THEN 1
            WHEN source_url LIKE "%politicops.com%" THEN 1
            WHEN source_url LIKE "%prisonplanet.com%" THEN 1
            WHEN source_url LIKE "%react365.com%" THEN 1
            WHEN source_url LIKE "%redflagnews.com%" THEN 1
            WHEN source_url LIKE "%thedailysheeple.com%" THEN 1
            WHEN source_url LIKE "%thenewsnerd.com%" THEN 1
            WHEN source_url LIKE "%therundownlive.com%" THEN 1
            WHEN source_url LIKE "%truthfrequencyradio.com%" THEN 1
            WHEN source_url LIKE "%USAToday.com.co%" THEN 1
            WHEN source_url LIKE "%weeklyworldnews.com%" THEN 1
            WHEN source_url LIKE "%witscience.org%" THEN 1
            WHEN source_url LIKE "%wnd.com%" THEN 1
            WHEN source_url LIKE "%anonews.co%" THEN 1
            WHEN source_url LIKE "%bigamericannews.com%" THEN 1
            WHEN source_url LIKE "%callthecops.net%" THEN 1
            WHEN source_url LIKE "%collective-evolution.com%" THEN 1
            WHEN source_url LIKE "%dailycaller.com%" THEN 1
            WHEN source_url LIKE "%denverguardian.com%" THEN 1
            WHEN source_url LIKE "%derfmagazine.com%" THEN 1
            WHEN source_url LIKE "%empireherald.com%" THEN 1
            WHEN source_url LIKE "%endingthefed.com%" THEN 1
            WHEN source_url LIKE "%globalassociatednews.com%" THEN 1
            WHEN source_url LIKE "%humansarefree.com%" THEN 1
            WHEN source_url LIKE "%ifyouonlynews.com%" THEN 1
            WHEN source_url LIKE "%itaglive.com%" THEN 1
            WHEN source_url LIKE "%libertyvideos.org%" THEN 1
            WHEN source_url LIKE "%madworldnews.com%" THEN 1
            WHEN source_url LIKE "%ncscooper.com%" THEN 1
            WHEN source_url LIKE "%newsexaminer.com%" THEN 1
            WHEN source_url LIKE "%occupydemocrats.com%" THEN 1
            WHEN source_url LIKE "%other98.com%" THEN 1
            WHEN source_url LIKE "%politicalblindspot.com%" THEN 1
            WHEN source_url LIKE "%politicalears.com%" THEN 1
            WHEN source_url LIKE "%realfarmacy.com%" THEN 1
            WHEN source_url LIKE "%redstate.com%" THEN 1
            WHEN source_url LIKE "%rt.com%" THEN 1
            WHEN source_url LIKE "%satiratribune.com%" THEN 1
            WHEN source_url LIKE "%sputniknews.com%" THEN 1
            WHEN source_url LIKE "%thebostontribune.com%" THEN 1
            WHEN source_url LIKE "%thefreethoughtproject.com%" THEN 1
            WHEN source_url LIKE "%thelapine.ca%" THEN 1
            WHEN source_url LIKE "%thespoof.com%" THEN 1
            WHEN source_url LIKE "%theuspatriot.com%" THEN 1
            WHEN source_url LIKE "%truepundit.com%" THEN 1
            WHEN source_url LIKE "%twitchy.com%" THEN 1
            WHEN source_url LIKE "%unconfirmedsources.com%" THEN 1
            WHEN source_url LIKE "%usuncut.com%" THEN 1
            WHEN source_url LIKE "%wakingupwisconsin.com%" THEN 1
            WHEN source_url LIKE "%yournewswire.com" THEN 1
            ELSE 0
        END as not_reputable,
        month,
        year
    from events_parquet
    where year >= 2017 and year <= 2019
    ) sq0
    group by sq0.year, sq0.month
    order by sq0.year, sq0.month
"""

start_time = time.time()
dfp = spark.sql(query).toPandas()
elapsed_time = time.time() - start_time
print(elapsed_time)
# Out:
# 99.4048769474

# %%
dfp.head(100)
# Out:
#     year  month      num  not_reputable
# 0   2017      1  6144894          72636
# 1   2017      2  6055968          77292
# 2   2017      3  6368174          76780
# 3   2017      4  5615147          66986
# 4   2017      5  5801996          66590
# 5   2017      6  5401707          61799
# 6   2017      7  5046430          58445
# 7   2017      8  5307354          62625
# 8   2017      9  5237471          53287
# 9   2017     10  5323151          53672
# 10  2017     11  5341312          51567
# 11  2017     12  4637962          50833
# 12  2018      1  5051092          54462
# 13  2018      2  4837577          52311
# 14  2018      3  5585566          59789
# 15  2018      4  5361310          61401
# 16  2018      5  5518302          60378
# 17  2018      6  5039461          53987
# 18  2018      7  4990580          61611
# 19  2018      8  5139643          68357
# 20  2018      9  4916944          63118
# 21  2018     10  5323981          72856
# 22  2018     11  5057920          67054
# 23  2018     12  4322609          57720
# 24  2019      1  4655244          65595
# 25  2019      2  4713397          63827
# 26  2019      3  5157770          65319
# 27  2019      4  3363751          43362

# %% [markdown]
# Now, we'll use some analytics queries to see how these sites are producing material month over month. We'll rank each sites months by the events they are creating and see how those months compare to the previous month in the results. We'll turn this into a Pandas dataframe and export the results as a CSV.

# %%
query = """
select
    sq1.source_url as source_url,
    sq1.events as events,
    sq1.events - (lag(sq1.events) over (partition by sq1.source_url order by sq1.year, sq1.month)) as events_diff,
    rank() over (partition by sq1.source_url order by sq1.events desc) as source_month_rank,
    sq1.year as year,
    sq1.month as month
from (
    select
        sq0.source_url as source_url,
        sum(sq0.not_reputable) as events,
        sq0.year as year,
        sq0.month as month,
        sq0.not_reputable
    from (
        select
            source_url,
            CASE
                WHEN source_url LIKE "%nationalreport.net%" THEN 1
                WHEN source_url LIKE "%huzlers.com%" THEN 1
                WHEN source_url LIKE "%infowars.com%" THEN 1
                WHEN source_url LIKE "%theonion.com%" THEN 1
                WHEN source_url LIKE "%empirenews.net%" THEN 1
                WHEN source_url LIKE "%activistpost.com%" THEN 1
                WHEN source_url LIKE "%americannews.com%" THEN 1
                WHEN source_url LIKE "%christwire.org%" THEN 1
                WHEN source_url LIKE "%civictribune.com%" THEN 1
                WHEN source_url LIKE "%duffelblog.com%" THEN 1
                WHEN source_url LIKE "%en.mediamass.net%" THEN 1
                WHEN source_url LIKE "%naturalnews.com%" THEN 1
                WHEN source_url LIKE "%realnewsrightnow.com%" THEN 1
                WHEN source_url LIKE "%rilenews.com%" THEN 1
                WHEN source_url LIKE "%thedcgazette.com%" THEN 1
                WHEN source_url LIKE "%worldnewsdailyreport.com%" THEN 1
                WHEN source_url LIKE "%21stcenturywire.com%" THEN 1
                WHEN source_url LIKE "%70news.wordpress.com%" THEN 1
                WHEN source_url LIKE "%beforeitsnews.com%" THEN 1
                WHEN source_url LIKE "%breitbart.com%" THEN 1
                WHEN source_url LIKE "%clickhole.com%" THEN 1
                WHEN source_url LIKE "%coasttocoastam.com%" THEN 1
                WHEN source_url LIKE "%consciouslifenews.com%" THEN 1
                WHEN source_url LIKE "%conservativeoutfitters.com%" THEN 1
                WHEN source_url LIKE "%countdowntozerotime.com%" THEN 1
                WHEN source_url LIKE "%creambmp.com%" THEN 1
                WHEN source_url LIKE "%dailybuzzlive.com%" THEN 1
                WHEN source_url LIKE "%disclose.tv%" THEN 1
                WHEN source_url LIKE "%empiresports.co%" THEN 1
                WHEN source_url LIKE "%globalresearch.ca%" THEN 1
                WHEN source_url LIKE "%newslo.com%" THEN 1
                WHEN source_url LIKE "%newsmutiny.com%" THEN 1
                WHEN source_url LIKE "%veteranstoday.com%" THEN 1
                WHEN source_url LIKE "%worldtruth.tv%" THEN 1
                WHEN source_url LIKE "%abcnews.com.co%" THEN 1
                WHEN source_url LIKE "%addictinginfo.org%" THEN 1
                WHEN source_url LIKE "%bipartisanreport.com%" THEN 1
                WHEN source_url LIKE "%bluenationreview.com%" THEN 1
                WHEN source_url LIKE "%chronicle.su%" THEN 1
                WHEN source_url LIKE "%counterpsyops.com%" THEN 1
                WHEN source_url LIKE "%dailycurrant.com%" THEN 1
                WHEN source_url LIKE "%dcclothesline.com%" THEN 1
                WHEN source_url LIKE "%duhprogressive.com%" THEN 1
                WHEN source_url LIKE "%enduringvision.com%" THEN 1
                WHEN source_url LIKE "%fprnradio.com%" THEN 1
                WHEN source_url LIKE "%geoengineeringwatch.org%" THEN 1
                WHEN source_url LIKE "%govtslaves.info%" THEN 1
                WHEN source_url LIKE "%gulagbound.com%" THEN 1
                WHEN source_url LIKE "%hangthebankers.com%" THEN 1
                WHEN source_url LIKE "%intellihub.com%" THEN 1
                WHEN source_url LIKE "%jonesreport.com%" THEN 1
                WHEN source_url LIKE "%lewrockwell.com%" THEN 1
                WHEN source_url LIKE "%libertymovementradio.com%" THEN 1
                WHEN source_url LIKE "%libertytalk.fm%" THEN 1
                WHEN source_url LIKE "%newsbiscuit.com%" THEN 1
                WHEN source_url LIKE "%newswire-24.com%" THEN 1
                WHEN source_url LIKE "%nodisinfo.com%" THEN 1
                WHEN source_url LIKE "%now8news.com%" THEN 1
                WHEN source_url LIKE "%nowtheendbegins.com%" THEN 1
                WHEN source_url LIKE "%pakalertpress.com%" THEN 1
                WHEN source_url LIKE "%politicops.com%" THEN 1
                WHEN source_url LIKE "%prisonplanet.com%" THEN 1
                WHEN source_url LIKE "%react365.com%" THEN 1
                WHEN source_url LIKE "%redflagnews.com%" THEN 1
                WHEN source_url LIKE "%thedailysheeple.com%" THEN 1
                WHEN source_url LIKE "%thenewsnerd.com%" THEN 1
                WHEN source_url LIKE "%therundownlive.com%" THEN 1
                WHEN source_url LIKE "%truthfrequencyradio.com%" THEN 1
                WHEN source_url LIKE "%USAToday.com.co%" THEN 1
                WHEN source_url LIKE "%weeklyworldnews.com%" THEN 1
                WHEN source_url LIKE "%witscience.org%" THEN 1
                WHEN source_url LIKE "%wnd.com%" THEN 1
                WHEN source_url LIKE "%anonews.co%" THEN 1
                WHEN source_url LIKE "%bigamericannews.com%" THEN 1
                WHEN source_url LIKE "%callthecops.net%" THEN 1
                WHEN source_url LIKE "%collective-evolution.com%" THEN 1
                WHEN source_url LIKE "%dailycaller.com%" THEN 1
                WHEN source_url LIKE "%denverguardian.com%" THEN 1
                WHEN source_url LIKE "%derfmagazine.com%" THEN 1
                WHEN source_url LIKE "%empireherald.com%" THEN 1
                WHEN source_url LIKE "%endingthefed.com%" THEN 1
                WHEN source_url LIKE "%globalassociatednews.com%" THEN 1
                WHEN source_url LIKE "%humansarefree.com%" THEN 1
                WHEN source_url LIKE "%ifyouonlynews.com%" THEN 1
                WHEN source_url LIKE "%itaglive.com%" THEN 1
                WHEN source_url LIKE "%libertyvideos.org%" THEN 1
                WHEN source_url LIKE "%madworldnews.com%" THEN 1
                WHEN source_url LIKE "%ncscooper.com%" THEN 1
                WHEN source_url LIKE "%newsexaminer.com%" THEN 1
                WHEN source_url LIKE "%occupydemocrats.com%" THEN 1
                WHEN source_url LIKE "%other98.com%" THEN 1
                WHEN source_url LIKE "%politicalblindspot.com%" THEN 1
                WHEN source_url LIKE "%politicalears.com%" THEN 1
                WHEN source_url LIKE "%realfarmacy.com%" THEN 1
                WHEN source_url LIKE "%redstate.com%" THEN 1
                WHEN source_url LIKE "%.rt.com%" THEN 1
                WHEN source_url LIKE "%satiratribune.com%" THEN 1
                WHEN source_url LIKE "%sputniknews.com%" THEN 1
                WHEN source_url LIKE "%thebostontribune.com%" THEN 1
                WHEN source_url LIKE "%thefreethoughtproject.com%" THEN 1
                WHEN source_url LIKE "%thelapine.ca%" THEN 1
                WHEN source_url LIKE "%thespoof.com%" THEN 1
                WHEN source_url LIKE "%theuspatriot.com%" THEN 1
                WHEN source_url LIKE "%truepundit.com%" THEN 1
                WHEN source_url LIKE "%twitchy.com%" THEN 1
                WHEN source_url LIKE "%unconfirmedsources.com%" THEN 1
                WHEN source_url LIKE "%usuncut.com%" THEN 1
                WHEN source_url LIKE "%wakingupwisconsin.com%" THEN 1
                WHEN source_url LIKE "%yournewswire.com" THEN 1
                ELSE 0
            END as not_reputable,
            month,
            year
        from events_parquet
        where year >= 2017 and year <= 2019
        ) sq0
    where sq0.not_reputable=1
    group by
        sq0.source_url, sq0.not_reputable, sq0.year, sq0.month
    order by
        sq0.source_url, sq0.not_reputable, sq0.year, sq0.month
) sq1
order by sq1.source_url, sq1.year, sq1.month
"""

start_time = time.time()
dfp = spark.sql(query).toPandas()
elapsed_time = time.time() - start_time
print(elapsed_time)
# Out:
# 93.8160510063

# %%
dfp.head()
# Out:
#             source_url  events  events_diff  source_month_rank  year  month
# 0  21stcenturywire.com     414          NaN                  7  2017      1
# 1  21stcenturywire.com     552        138.0                  1  2017      2
# 2  21stcenturywire.com     460        -92.0                  4  2017      3
# 3  21stcenturywire.com     364        -96.0                 12  2017      4
# 4  21stcenturywire.com     529        165.0                  2  2017      5

# %%
dfp.size
# Out:
# 5388

# %%
dfp.to_csv('unreputable_source_month_rank.csv')
